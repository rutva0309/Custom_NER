# %%
import re

# %%
text = ["i would like to withdrawal 10 using eft from my Grindrod Bank account",
    "i would like to withdrawal 160  using eft from Grindrod account", 
    "i would like to withdrawal 1000rand using eft from standard bank account", 
    "i would like to withdrawal 101 rand using eft from Standard Bank account", 
    "i would like to withdraw 50 rand from Grindrod account via eft", 
    "please withdrawl 67 rand using eft from Grindrod account", 
    "i would like to withdraw 14 rand from Standard Bank account via eft", 
    "i want to withdrawal 150 from my Investec account", 
    "i would like to withdraw 201 rand from Marchantile account.", 
    "i would like to withdraw 250  from Grindrod Bank using eft", 
    "please withdrawl 43rand using eft from Grindrod Bank account", 
    "please withdrawl 67 rand using eft from Standard Bank account", 
    "please withdrawl 289  using eft from Investec account", 
    "please withdrawl 67  using eft from Marchantile account",
    "i would like to withdraw 201 rand from Marchantile account using eft",
    "i want to withdrawal 108 rand from my Investec account", 
    "want to withdrawal 109 rand from my Marchantile Bank account", 
    "i want to withdrawal 98  from Investec Bank via eft", 
    "want to withdrawal 211 rand using eft from my Investec account", 
    "Brajkishore Prajapati has 500 rand in the Investec Bank."]

# %%
x = re.findall('[0-9]+', str(text))
print(x)
# Out:
# ['10', '160', '1000', '101', '50', '67', '14', '150', '201', '250', '43', '67', '289', '67', '201', '10', '109', '98', '211', '500']

# %%
out = [i for i in str(text).split('_')[1:] if len(i)==4 and i.isalpha() and i.isupper()]
print(out) # ['DE']
# Out:
# []

# %%
word = ['rand']
regex = r'\b(?:' + '|'.join(word) + r')\b'
matches = re.findall(regex, str(text))
# Out:
# ['rand', 'rand', 'rand', 'rand', 'rand', 'rand', 'rand', 'rand', 'rand', 'rand', 'rand', 'rand', 'rand', 'rand', 'rand', 'rand', 'rand', 'rand', 'rand', 'rand']

# %%
x = re.findall('[0-9]+', str(text))

# %%
import re
x = re.findall('[0-9]+', str(text))
word = ['rand']
regex = r'\b(?:' + '|'.join(word) + r')\b'
matches = re.findall(regex, str(text))
digit = []
if str(word) not in text:
    digit.append(x)
print(digit)
amount = []
for i in zip(x,matches):
    amount.append(i[0]+ ' ' +i[1])
amount

# %%
x = re.findall('[0-9]+' ' rand', str(text))
x
# Out:
# ['1000 rand',
#  '101 rand',
#  '50 rand',
#  '67 rand',
#  '14 rand',
#  '201 rand',
#  '43 rand',
#  '67 rand',
#  '201 rand',
#  '108 rand',
#  '109 rand',
#  '211 rand',
#  '500 rand']

# %%
word = 'rand'
x = re.findall('[0-9]+', str(text))
digit = []
if word not in text.split():
    digit.append(x)
print(digit)
# Out:
# [['10', '160', '1000', '101', '50', '67', '14', '150', '201', '250', '43', '67', '289', '67', '201', '108', '109', '98', '211', '500']]

# %%
s = "i would like to withdraw 100 rand "
y = re.search('[0-9]+\s*(' 'rand|rand)?' , s)
y.group()
# Out:
# '100 rand'

# %%
s = "i would like to withdraw 100rand "
print(re.search('[0-9]+\s*(' 'rand|rand)?' , s).group())
# Out:
# 100rand

# %%
amount=[]
word ='rand'
for txt in text:
    amount.append(re.search('[0-9]+\s*(' 'rand|rand)?' , txt).group())
amount=[x.strip() for x in amount]
print(amount)
# Out:
# ['10', '160', '1000rand', '101 rand', '50 rand', '67 rand', '14 rand', '150', '201 rand', '250', '43rand', '67 rand', '289', '67', '201 rand', '108 rand', '109 rand', '98', '211 rand', '500 rand']

# %%
dw
# Out:
# ['10', '160', '1000rand', '150', '250', '43rand', '289', '67', '98']

# %%
 word = 'rand'
 x = re.findall('[0-9]+' ' rand', str(text))
 y = re.findall('[0-9]+', str(text))
#  if word not in str(text).split():
#      print(y)
z =  [i for i in str(text).split() if i!=word]
z
# Out:
# ["['i",
#  'would',
#  'like',
#  'to',
#  'withdrawal',
#  '10',
#  'using',
#  'eft',
#  'from',
#  'my',
#  'Grindrod',
#  'Bank',
#  "account',",
#  "'i",
#  'would',
#  'like',
#  'to',
#  'withdrawal',
#  '160',
#  'using',
#  'eft',
#  'from',
#  'Grindrod',
#  "account',",
#  "'i",
#  'would',
#  'like',
#  'to',
#  'withdrawal',
#  '1000',
#  'using',
#  'eft',
#  'from',
#  'Standard',
#  'Bank',
#  "account',",
#  "'i",
#  'would',
#  'like',
#  'to',
#  'withdrawal',
#  '101',
#  'using',
#  'eft',
#  'from',
#  'Standard',
#  'Bank',
#  "account',",
#  "'i",
#  'would',
#  'like',
#  'to',
#  'withdraw',
#  '50',
#  'from',
#  'Grindrod',
#  'account',
#  'via',
#  "eft',",
#  "'please",
#  'withdrawl',
#  '67',
#  'using',
#  'eft',
#  'from',
#  'Grindrod',
#  "account',",
#  "'i",
#  'would',
#  'like',
#  'to',
#  'withdraw',
#  '14',
#  'from',
#  'Standard',
#  'Bank',
#  'account',
#  'via',
#  "eft',",
#  "'i",
#  'want',
#  'to',
#  'withdrawal',
#  '150',
# ...

# %%
amount=[]
for txt in text:
    x = re.findall('[0-9]+' ' rand', str(txt))
    y = re.findall('[0-9]+rand', str(txt))
    if x:
        amount.append(x[0])
    elif y:
        amount.append(y[0])
    else:
        amount.append(re.findall('[0-9]+', str(text))[0])

# %%
amount
# Out:
# ['10',
#  '10',
#  '1000rand',
#  '101 rand',
#  '50 rand',
#  '67 rand',
#  '14 rand',
#  '10',
#  '201 rand',
#  '10',
#  '43rand',
#  '67 rand',
#  '10',
#  '10',
#  '201 rand',
#  '108 rand',
#  '109 rand',
#  '10',
#  '211 rand',
#  '500 rand']

# %%
import re
def check():
    x = re.findall('[0-9]+' ' rand', str(text))
    y = re.findall('[0-9]+rand', str(text))
    if x:
        return x[0]
    elif y:
        return y[0]
    else:        
        return re.findall('[0-9]+', str(text))[0]
    
op =  list(map(check, text))
op
# Out:
# ['10',
#  '160',
#  '1000rand',
#  '101 rand',
#  '50 rand',
#  '67 rand',
#  '14 rand',
#  '150',
#  '201 rand',
#  '250',
#  '43rand',
#  '67 rand',
#  '289',
#  '67',
#  '201 rand',
#  '108 rand',
#  '109 rand',
#  '98',
#  '211 rand',
#  '500 rand']

# %%
z
# Out:
# ["['i",
#  'would',
#  'like',
#  'to',
#  'withdrawal',
#  '10',
#  'using',
#  'eft',
#  'from',
#  'my',
#  'Grindrod',
#  'Bank',
#  "account',",
#  "'i",
#  'would',
#  'like',
#  'to',
#  'withdrawal',
#  '160',
#  'using',
#  'eft',
#  'from',
#  'Grindrod',
#  "account',",
#  "'i",
#  'would',
#  'like',
#  'to',
#  'withdrawal',
#  '1000',
#  'using',
#  'eft',
#  'from',
#  'Standard',
#  'Bank',
#  "account',",
#  "'i",
#  'would',
#  'like',
#  'to',
#  'withdrawal',
#  '101',
#  'using',
#  'eft',
#  'from',
#  'Standard',
#  'Bank',
#  "account',",
#  "'i",
#  'would',
#  'like',
#  'to',
#  'withdraw',
#  '50',
#  'from',
#  'Grindrod',
#  'account',
#  'via',
#  "eft',",
#  "'please",
#  'withdrawl',
#  '67',
#  'using',
#  'eft',
#  'from',
#  'Grindrod',
#  "account',",
#  "'i",
#  'would',
#  'like',
#  'to',
#  'withdraw',
#  '14',
#  'from',
#  'Standard',
#  'Bank',
#  'account',
#  'via',
#  "eft',",
#  "'i",
#  'want',
#  'to',
#  'withdrawal',
#  '150',
# ...
